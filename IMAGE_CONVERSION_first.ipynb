# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
im = Image.open('part1.png', 'r')

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x1599 at 0x1FD8FA40310>

# %%
pix_val = list(im.getdata())

# %%
pix_val_flat = [x for sets in pix_val for x in sets]

# %%
plt.gray()
plt.matshow(pix_val_flat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_9564/28008322.py in <module>
#       1 plt.gray()
# ----> 2 plt.matshow(pix_val_flat)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in matshow(A, fignum, **kwargs)
#    2458         # Extract actual aspect ratio of array and make appropriately sized
#    2459         # figure.
# -> 2460         fig = figure(fignum, figsize=figaspect(A))
#    2461         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
#    2462     im = ax.matshow(A, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in figaspect(arg)
#    3226     # Extract the aspect ratio of the array
#    3227     if isarray:
# -> 3228         nr, nc = arg.shape[:2]
#    3229         arr_ratio = nr / nc
#    3230     else:
#
# ...

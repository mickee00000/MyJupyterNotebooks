# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
import tensorflow_hub as tf_hub
from tensorflow import keras

# %%
import PIL.Image as Image
import os
import cv2
import pathlib

# %%
IMAGE_SHAPE = (224, 224)

pretrained = keras.Sequential([
    tf_hub.KerasLayer('https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4' , input_shape=IMAGE_SHAPE+(3,))
])

# %%
gold_fish = Image.open("goldfish.jpg").resize(IMAGE_SHAPE)
gold_fish
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1FACA456FD0>

# %%
fish_label = []

with open('ImageNetLabels.txt', 'r') as f:
    fish_labels = f.read().splitlines()
fish_labels
# Out:
# ['background',
#  'tench',
#  'goldfish',
#  'great white shark',
#  'tiger shark',
#  'hammerhead',
#  'electric ray',
#  'stingray',
#  'cock',
#  'hen',
#  'ostrich',
#  'brambling',
#  'goldfinch',
#  'house finch',
#  'junco',
#  'indigo bunting',
#  'robin',
#  'bulbul',
#  'jay',
#  'magpie',
#  'chickadee',
#  'water ouzel',
#  'kite',
#  'bald eagle',
#  'vulture',
#  'great grey owl',
#  'European fire salamander',
#  'common newt',
#  'eft',
#  'spotted salamander',
#  'axolotl',
#  'bullfrog',
#  'tree frog',
#  'tailed frog',
#  'loggerhead',
#  'leatherback turtle',
#  'mud turtle',
#  'terrapin',
#  'box turtle',
#  'banded gecko',
#  'common iguana',
#  'American chameleon',
#  'whiptail',
#  'agama',
#  'frilled lizard',
#  'alligator lizard',
#  'Gila monster',
#  'green lizard',
#  'African chameleon',
#  'Komodo dragon',
#  'African crocodile',
#  'American alligator',
#  'triceratops',
#  'thunder snake',
#  'ringneck snake',
#  'hognose snake',
# ...

# %%
gold_fish = np.array(gold_fish)

# %%
gold_fish
# Out:
# array([[[ 72,  85,  18],
#         [ 80,  95,  23],
#         [ 89, 107,  30],
#         ...,
#         [ 84, 100,   1],
#         [ 82,  98,   1],
#         [ 79,  94,   0]],
#
#        [[ 73,  85,  21],
#         [ 83,  97,  28],
#         [ 90, 108,  33],
#         ...,
#         [ 82,  97,   1],
#         [ 80,  95,   1],
#         [ 77,  92,   0]],
#
#        [[ 73,  85,  22],
#         [ 80,  94,  26],
#         [ 88, 106,  33],
#         ...,
#         [ 81,  96,   1],
#         [ 79,  94,   2],
#         [ 76,  91,   1]],
#
#        ...,
#
#        [[ 14,  28,   4],
#         [ 13,  29,   5],
#         [ 13,  31,   6],
#         ...,
#         [ 40,  56,  10],
#         [ 40,  57,   9],
#         [ 41,  57,   8]],
#
#        [[ 16,  32,   4],
#         [ 15,  34,   5],
#         [ 14,  35,   5],
#         ...,
#         [ 35,  52,  12],
#         [ 36,  53,  11],
#         [ 36,  53,   9]],
#
#        [[ 17,  37,   3],
#         [ 18,  39,   5],
#         [ 14,  38,   3],
# ...

# %%
gold_fish.shape
# Out:
# (224, 224, 3)

# %%
plt.matshow(gold_fish)

# %%
plt.matshow(new_gold)

# %%
new_gold = cv2.imread('goldfish.jpg')

# %%
new_gold
# Out:
# array([[[17, 83, 71],
#         [17, 86, 73],
#         [20, 89, 76],
#         ...,
#         [ 1, 96, 81],
#         [ 0, 95, 80],
#         [ 0, 94, 79]],
#
#        [[16, 82, 70],
#         [18, 84, 72],
#         [20, 89, 76],
#         ...,
#         [ 1, 96, 81],
#         [ 0, 94, 79],
#         [ 1, 94, 79]],
#
#        [[15, 81, 69],
#         [18, 84, 72],
#         [21, 90, 77],
#         ...,
#         [ 0, 95, 80],
#         [ 0, 93, 78],
#         [ 0, 92, 77]],
#
#        ...,
#
#        [[ 1, 33, 16],
#         [ 2, 34, 15],
#         [ 3, 35, 16],
#         ...,
#         [11, 51, 33],
#         [11, 51, 33],
#         [ 9, 51, 33]],
#
#        [[ 3, 35, 16],
#         [ 4, 36, 17],
#         [ 5, 37, 18],
#         ...,
#         [10, 48, 30],
#         [10, 48, 30],
#         [10, 48, 30]],
#
#        [[ 3, 38, 18],
#         [ 4, 39, 19],
#         [ 5, 41, 19],
#         ...,
#         [ 9, 45, 28],
#         [ 8, 46, 28],
#         [ 8, 46, 28]]], dtype=uint8)
